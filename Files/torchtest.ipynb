# %%
import pandas as pd
t = pd.read_csv("result.csv",encoding='latin-1')
question = t["Label"]

# %%
import os
import openai

openai.api_key = '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'

# %%
ft_qa = "ada:ft-personal-2023-03-20-17-19-13"

def apply_ft_qa_answer(context, answering_model):
    prompt = f"{context}generate question from this answer:"
    result = openai.Completion.create(model=answering_model, prompt=prompt, max_tokens=30, temperature=0, top_p=1, n=1, stop=['.','\n'])
    return result['choices'][0]['text']
output = []
for i in question:
    
    t = apply_ft_qa_answer(
        i,
        ft_qa
    )
    output.append(t)
    print(t)
# Out:
#  what is the name of a glacier cave
#  What is the force acting on the lever arm due to the force of the lever arm acting on the lever arm ?
#  how did apollo die
#  what is the term for federal judges ?
#  what is the capacity of a beretta bobcat pistol
#  What is a universal life insurance policy ?
#  what is the size of an outdoor wood boiler
#  what is girl Sut okie
#  what is the largest university in Purdue
#  what are sebaceous cysts
#  What are the main characteristics of pointe shoes ?
#  what is a tablespoon of water
#  how many harry potter books are there
#  What are rocket engines
#  what is the meaning of baby one more time
#  what is the disease cholera
#  what is the name of the novel that is considered the greatest gothic novel of all time ?
#  who is gabor boson
#  what was bruce lee 's last film
#  how much does copd cost
#  What was the name of the girl who wrote the diary ?
#  who killed kurt cobain
#  what is the mainspring of an aircraft radial engine
# ...

# %%
df['address'] = df['address'].str.replace(r'[^\x00-\x7F]+', '')
# Out:
# ' '

# %%
import re
def cleaning(s):
    s = str(s)
    s = re.sub('\s\W',' ',s)
    s = re.sub('\W,\s',' ',s)
    s = re.sub("\d+", "", s)
    s = re.sub('\s+',' ',s)
    s = re.sub('[!@#$_]', '', s)
    s = s.replace("co","")
    s = s.replace("https","")
    s = s.replace("[\w*"," ")
    s = s.replace("\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r"," ")

    return s
print(question[2].replace(r'[^\x00-\x7F]+', ''))
# Out:
# He was played by Carl Weathers .,All of Apollo 's championship fights were scheduled for the 15 round distance .,Championship fights did not convert from 15 rounds to 12 rounds until 1987 .,Balboa 's signature colors were black and goldâcolors he used in the latest movie .

# %%
print(t.decode().replace(r'[^\x00-\x7F]+', ''))
# Out:
# He was played by Carl Weathers .,All of Apollo 's championship fights were scheduled for the 15 round distance .,Championship fights did not convert from 15 rounds to 12 rounds until 1987 .,Balboa 's signature colors were black and goldâcolors he used in the latest movie .

# %%
for i in range(len(question)):
    
    question[i] = cleaning(question[i].encode("ascii","ignore").decode())

# %%
import csv
R="\n".join(output)
f = open('Columns.csv','w',encoding='utf-8')
f.write(R)
f.close()

# %%
def compute_metrics(metric, pred, actual):
    """ Compute the model's rouge performance on an instance. """

    metric.add(predictions=pred, references=actual)
    final_score = metric.compute()
    
    return final_score

# %%
import os
import sys
import argparse
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import f1_score
from datasets import load_dataset, load_metric
from transformers import DataCollatorForSeq2Seq, AdamWeightDecay, \
    T5ForConditionalGeneration,TFT5ForConditionalGeneration, T5Tokenizer



metric = load_metric('rouge')
result = [[] for x in range(3)]

cnt = 0
for i in range(len(output)):
    
    rouge_score = compute_metrics(metric, output[i], question[i])
    rouge1 = 100 * rouge_score['rouge1'][1][2]
    rouge2 = 100 * rouge_score['rouge2'][1][2]
    rougeL = 100 * rouge_score['rougeL'][1][2]

    cnt += 1 
    if cnt % 25 == 0:
        print(f'Round: {cnt * 4}')

    result[0].append(rouge1)
    result[1].append(rouge2)
    result[2].append(rougeL)
# Out:
# Round: 100
# Round: 200
# Round: 300
# Round: 400
# Round: 500
# Round: 600
# Round: 700
# Round: 800
# Round: 900
# Round: 1000
# Round: 1100
# Round: 1200
# Round: 1300
# Round: 1400
# Round: 1500
# Round: 1600
# Round: 1700
# Round: 1800
# Round: 1900
# Round: 2000
# Round: 2100
# Round: 2200
# Round: 2300
# Round: 2400
# Round: 2500
# Round: 2600
# Round: 2700
# Round: 2800
# Round: 2900
# Round: 3000
# Round: 3100
# Round: 3200
# Round: 3300
# Round: 3400
# Round: 3500
# Round: 3600
# Round: 3700
# Round: 3800
# Round: 3900
# Round: 4000
# Round: 4100
# Round: 4200
# Round: 4300
# Round: 4400
# Round: 4500
# Round: 4600
# Round: 4700
# Round: 4800
# Round: 4900
# Round: 5000
# Round: 5100
# Round: 5200
# Round: 5300
# Round: 5400
# Round: 5500
# Round: 5600
# Round: 5700
# Round: 5800
# Round: 5900
# Round: 6000
# Round: 6100
# Round: 6200
# Round: 6300
# Round: 6400
# Round: 6500
# Round: 6600
# Round: 6700
# Round: 6800
# Round: 6900
# Round: 7000
# Round: 7100
# Round: 7200
# ...

# %%
import csv
R="\n".join(str(result[0]))
f = open('Scores.csv','w')
f.write(R)
f.close()

# %%
result[0]
# Out:
# [27.272727272727277,
#  18.518518518518515,
#  8.695652173913041,
#  11.538461538461538,
#  46.15384615384615,
#  9.523809523809524,
#  35.29411764705882,
#  5.405405405405405,
#  18.51851851851852,
#  12.5,
#  12.903225806451612,
#  12.698412698412698,
#  11.764705882352942,
#  18.75,
#  9.929078014184398,
#  14.545454545454545,
#  25.454545454545453,
#  6.666666666666668,
#  6.896551724137931,
#  7.6923076923076925,
#  18.42105263157895,
#  5.714285714285714,
#  17.910447761194032,
#  3.7037037037037033,
#  2.923976608187135,
#  16.0,
#  8.51063829787234,
#  30.769230769230766,
#  9.523809523809524,
#  22.22222222222222,
#  11.11111111111111,
#  25.0,
#  7.228915662650602,
#  2.770083102493075,
#  10.0,
#  7.142857142857144,
#  31.57894736842105,
#  5.825242718446602,
#  14.705882352941178,
#  8.108108108108107,
#  29.629629629629626,
#  10.884353741496598,
#  17.20430107526882,
#  8.791208791208792,
#  0.0,
#  19.047619047619047,
#  3.389830508474576,
#  14.814814814814817,
# ...

# %%
dict = {"rouge1":result[0], "rouge2":result[1], "rougeL":result[2]}

# %%
df = pd.DataFrame(dict) 
    
# write the DataFrame to a CSV file
df.to_csv('Scores.csv')

# %%
import pandas as pd
file = pd.read_csv('Columns.csv')

# %%
print(file.head())
# Out:
#                                         gpt question  \
# 0                 what is the name of a glacier cave
# 1   What is the force acting on the lever arm due...
# 2                                 how did apollo die
# 3              what is the term for federal judges ?
# 4    what is the capacity of a beretta bobcat pistol
#
#                                        True Question     rouge1     rouge2  \
# 0                       how glacier caves was formed  27.272727  14.285714
# 1  Explain the relation between velocity and forc...  18.518519   3.846154
# 2                               how apollo creed die   8.695652   0.000000
# 3                    what is term for federal judges  11.538462   0.000000
# 4     how a beretta model 21 pistols magazines works  46.153846   0.000000
#
#       rougeL                                               Text Unnamed: 6  \
# 0  22.727273  A partly submerged glacier cave on Perito More...        NaN
# ...

# %%
true = file['True Question']
predict = file['gpt question']

# %%
from sklearn.metrics import f1_score

# %%
f1_score(true,predict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a30d9b67be54> in <module>
# ----> 1 f1_score(true,predict)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1121     modified with ``zero_division``.
#    1122     """
# -> 1123     return fbeta_score(
#    1124         y_true,
#    1125         y_pred,
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1259     """
#    1260
# -> 1261     _, _, f, _ = precision_recall_fscore_support(
#    1262         y_true,
#    1263         y_pred,
#
# ...
